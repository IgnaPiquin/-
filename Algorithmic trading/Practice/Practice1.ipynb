# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download('AAPL', start = '2010-01-01', end = '2021-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.496295
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.507527
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.404016
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.392176
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.434675
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  130.025925
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.676376
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.883224
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.750137
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.735336
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
ticker=['SPY','AAPL','KO']

# %%
stocks = yf.download(ticker, start = '2010-01-01', end = '2021-01-01')
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.496293  18.793238   87.791771    7.643214  28.520000
# 2010-01-05    6.507525  18.565897   88.024193    7.656429  28.174999
# 2010-01-06    6.404014  18.559319   88.086128    7.534643  28.165001
# 2010-01-07    6.392176  18.513182   88.458000    7.520714  28.094999
# 2010-01-08    6.434673  18.170532   88.752388    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  130.025925  49.557598  355.649139  131.970001  53.439999
# 2020-12-28  134.676392  50.225296  358.704437  136.690002  54.160000
# 2020-12-29  132.883179  50.197472  358.020142  134.869995  54.130001
# 2020-12-30  131.750153  50.484951  358.530975  133.720001  54.439999
# 2020-12-31  130.735336  50.855892  360.352600  132.690002  54.840000
#
# ...

# %%
stocks.head()
# Out:
#            Adj Close                           Close                         \
#                 AAPL         KO        SPY      AAPL         KO         SPY
# Date
# 2010-01-04  6.496293  18.793238  87.791771  7.643214  28.520000  113.330002
# 2010-01-05  6.507525  18.565897  88.024193  7.656429  28.174999  113.629997
# 2010-01-06  6.404014  18.559319  88.086128  7.534643  28.165001  113.709999
# 2010-01-07  6.392176  18.513182  88.458000  7.520714  28.094999  114.190002
# 2010-01-08  6.434673  18.170532  88.752388  7.570714  27.575001  114.570000
#
#                 High                              Low                         \
#                 AAPL         KO         SPY      AAPL         KO         SPY
# Date
# 2010-01-04  7.660714  28.610001  113.389999  7.585000  28.450001  111.510002
# 2010-01-05  7.699643  28.495001  113.680000  7.616071  28.070000  112.849998
# 2010-01-06  7.686786  28.219999  113.989998  7.526786  27.990000  113.430000
# ...

# %%
stocks.tail()
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2020-12-24  130.025925  49.557598  355.649139  131.970001  53.439999
# 2020-12-28  134.676392  50.225296  358.704437  136.690002  54.160000
# 2020-12-29  132.883179  50.197472  358.020142  134.869995  54.130001
# 2020-12-30  131.750153  50.484951  358.530975  133.720001  54.439999
# 2020-12-31  130.735336  50.855892  360.352600  132.690002  54.840000
#
#                               High                                Low  \
#                    SPY        AAPL         KO         SPY        AAPL
# Date
# 2020-12-24  369.000000  133.460007  53.549999  369.029999  131.100006
# 2020-12-28  372.170013  137.339996  54.439999  372.589996  133.509995
# 2020-12-29  371.459991  138.789993  54.490002  374.000000  134.339996
# 2020-12-30  371.989990  135.990005  54.630001  373.100006  133.399994
# ...

# %%
stock.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 stock.info()
#
# NameError: name 'stock' is not defined

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2769 entries, 2010-01-04 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2769 non-null   float64
#  1   (Adj Close, KO)    2769 non-null   float64
#  2   (Adj Close, SPY)   2769 non-null   float64
#  3   (Close, AAPL)      2769 non-null   float64
#  4   (Close, KO)        2769 non-null   float64
#  5   (Close, SPY)       2769 non-null   float64
#  6   (High, AAPL)       2769 non-null   float64
#  7   (High, KO)         2769 non-null   float64
#  8   (High, SPY)        2769 non-null   float64
#  9   (Low, AAPL)        2769 non-null   float64
#  10  (Low, KO)          2769 non-null   float64
#  11  (Low, SPY)         2769 non-null   float64
#  12  (Open, AAPL)       2769 non-null   float64
#  13  (Open, KO)         2769 non-null   float64
#  14  (Open, SPY)        2769 non-null   float64
# ...

# %%
stocks.to_csv('StocksPractice1.csv')

# %%
pd_stocks = pd.read_csv('StocksPractice1.csv')

# %%
pd_stocks
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN                AAPL                  KO                 SPY
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04   6.496293067932129  18.793237686157227    87.7917709350586
# 3     2010-01-05   6.507525444030762   18.56589698791504    88.0241928100586
# 4     2010-01-06   6.404013633728027   18.55931854248047   88.08612823486328
# ...          ...                 ...                 ...                 ...
# 2766  2020-12-24   130.0259246826172   49.55759811401367   355.6491394042969
# 2767  2020-12-28   134.6763916015625   50.22529602050781   358.7044372558594
# 2768  2020-12-29   132.8831787109375  50.197471618652344   358.0201416015625
# 2769  2020-12-30  131.75015258789062   50.48495101928711   358.5309753417969
# 2770  2020-12-31  130.73533630371094  50.855892181396484  360.35260009765625
#
# ...

# %%
pd_stocks = pd.read_csv('StocksPractice1.csv', header=[0,1])

# %%
pd_stocks
# Out:
#      Unnamed: 0_level_0   Adj Close                              Close  \
#      Unnamed: 0_level_1        AAPL         KO         SPY        AAPL
# 0                  Date         NaN        NaN         NaN         NaN
# 1            2010-01-04    6.496293  18.793238   87.791771    7.643214
# 2            2010-01-05    6.507525  18.565897   88.024193    7.656429
# 3            2010-01-06    6.404014  18.559319   88.086128    7.534643
# 4            2010-01-07    6.392176  18.513182   88.458000    7.520714
# ...                 ...         ...        ...         ...         ...
# 2765         2020-12-24  130.025925  49.557598  355.649139  131.970001
# 2766         2020-12-28  134.676392  50.225296  358.704437  136.690002
# 2767         2020-12-29  132.883179  50.197472  358.020142  134.869995
# 2768         2020-12-30  131.750153  50.484951  358.530975  133.720001
# 2769         2020-12-31  130.735336  50.855892  360.352600  132.690002
#
# ...

# %%
pd_stocks = pd.read_csv('StocksPractice1.csv', header=[0,5])

# %%
pd_stocks
# Out:
#      Unnamed: 0_level_0   Adj Close                              Close  \
#      Unnamed: 0_level_1        AAPL         KO         SPY        AAPL
# 0                  Date         NaN        NaN         NaN         NaN
# 1            2010-01-04    6.496293  18.793238   87.791771    7.643214
# 2            2010-01-05    6.507525  18.565897   88.024193    7.656429
# 3            2010-01-06    6.404014  18.559319   88.086128    7.534643
# 4            2010-01-07    6.392176  18.513182   88.458000    7.520714
# ...                 ...         ...        ...         ...         ...
# 2765         2020-12-24  130.025925  49.557598  355.649139  131.970001
# 2766         2020-12-28  134.676392  50.225296  358.704437  136.690002
# 2767         2020-12-29  132.883179  50.197472  358.020142  134.869995
# 2768         2020-12-30  131.750153  50.484951  358.530975  133.720001
# 2769         2020-12-31  130.735336  50.855892  360.352600  132.690002
#
# ...

# %%
pd_stocks = pd.read_csv('StocksPractice1.csv', header=[0,1], index_col=[0])

# %%
pd_stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.496293  18.793238   87.791771    7.643214  28.520000
# 2010-01-05    6.507525  18.565897   88.024193    7.656429  28.174999
# 2010-01-06    6.404014  18.559319   88.086128    7.534643  28.165001
# 2010-01-07    6.392176  18.513182   88.458000    7.520714  28.094999
# 2010-01-08    6.434673  18.170532   88.752388    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  130.025925  49.557598  355.649139  131.970001  53.439999
# 2020-12-28  134.676392  50.225296  358.704437  136.690002  54.160000
# 2020-12-29  132.883179  50.197472  358.020142  134.869995  54.130001
# 2020-12-30  131.750153  50.484951  358.530975  133.720001  54.439999
# 2020-12-31  130.735336  50.855892  360.352600  132.690002  54.840000
#
# ...

# %%
pd_stocks = pd.read_csv('StocksPractice1.csv', header=[0,1], index_col=[0], parse_dates=[0])

# %%
pd_stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.496293  18.793238   87.791771    7.643214  28.520000
# 2010-01-05    6.507525  18.565897   88.024193    7.656429  28.174999
# 2010-01-06    6.404014  18.559319   88.086128    7.534643  28.165001
# 2010-01-07    6.392176  18.513182   88.458000    7.520714  28.094999
# 2010-01-08    6.434673  18.170532   88.752388    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  130.025925  49.557598  355.649139  131.970001  53.439999
# 2020-12-28  134.676392  50.225296  358.704437  136.690002  54.160000
# 2020-12-29  132.883179  50.197472  358.020142  134.869995  54.130001
# 2020-12-30  131.750153  50.484951  358.530975  133.720001  54.439999
# 2020-12-31  130.735336  50.855892  360.352600  132.690002  54.840000
#
# ...

# %%
pd_stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
pd_stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
#Convert mult index to one tuple
pd_stocks.columns=pd_stocks.columns.to_flat_index()

# %%
pd_stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
pd_stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.496293        18.793238         87.791771
# 2010-01-05           6.507525        18.565897         88.024193
# 2010-01-06           6.404014        18.559319         88.086128
# 2010-01-07           6.392176        18.513182         88.458000
# 2010-01-08           6.434673        18.170532         88.752388
# ...                       ...              ...               ...
# 2020-12-24         130.025925        49.557598        355.649139
# 2020-12-28         134.676392        50.225296        358.704437
# 2020-12-29         132.883179        50.197472        358.020142
# 2020-12-30         131.750153        50.484951        358.530975
# 2020-12-31         130.735336        50.855892        360.352600
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# ...

# %%
# Convert back to multi Index
pd_stocks.columns=pd.MultiIndex.from_tuples(pd_stocks.columns)

# %%
pd_stocks.describe()
# Out:
#        (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  (Close, AAPL)  \
# count        2769.000000      2769.000000       2769.000000    2769.000000
# mean           31.646825        32.722795        183.435247      33.777537
# std            24.680505         8.314333         70.233047      24.572747
# min             5.829697        16.635138         79.874092       6.858929
# 25%            15.241903        27.030161        115.753883      17.484285
# 50%            24.614788        32.275932        177.317841      26.987499
# 75%            41.040897        38.229042        243.770523      43.007500
# max           134.676392        53.916515        360.352600     136.690002
#
#        (Close, KO)  (Close, SPY)  (High, AAPL)   (High, KO)  (High, SPY)  \
# count  2769.000000   2769.000000   2769.000000  2769.000000  2769.000000
# mean     41.320121    207.676797     34.114230    41.583236   208.716963
# ...

# %%
close=pd_stocks.loc[:,'Close'].copy()

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# Out:
# C:\Users\Ignacio\AppData\Local\Temp\ipykernel_13868\1843973781.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
close.iloc[0,0]
# Out:
# 7.643214225769043

# %%
close.iloc[0]
# Out:
# AAPL      7.643214
# KO       28.520000
# SPY     113.330002
# Name: 2010-01-04 00:00:00, dtype: float64

# %%
close.div(close.iloc[0]).mul(100)
# Out:
#                    AAPL          KO         SPY
# Date
# 2010-01-04   100.000000  100.000000  100.000000
# 2010-01-05   100.172893   98.790318  100.264710
# 2010-01-06    98.579511   98.755261  100.335302
# 2010-01-07    98.397266   98.509814  100.758846
# 2010-01-08    99.051443   96.686537  101.094148
# ...                 ...         ...         ...
# 2020-12-24  1726.629626  187.377271  325.597806
# 2020-12-28  1788.383766  189.901820  328.394959
# 2020-12-29  1764.571699  189.796635  327.768451
# 2020-12-30  1749.525753  190.883583  328.236111
# 2020-12-31  1736.049763  192.286112  329.903820
#
# [2769 rows x 3 columns]

# %%
NormClose=close.div(close.iloc[0]).mul(100)

# %%
NormClose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
aapl = close.AAPL.copy().to_frame()

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
aapl.shift()
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2010-01-04         NaN
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# 2010-01-08    7.520714
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2769 rows x 1 columns]

# %%
aapl['lag1']=aapl.shift(periods=1)

# %%
aapl
# Out:
#                   AAPL        lag1
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# 2010-01-08    7.570714    7.520714
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2769 rows x 2 columns]

# %%
aapl['Diff']=aapl.AAPL.sub(aapl.lag1)

# %%
aapl['% Change']=aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999   -0.770265
#
# [2769 rows x 6 columns]

# %%
aapl['Diff2']=aapl.AAPL.diff(periods=1)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  1.035766  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297 -1.029999
#
# [2769 rows x 5 columns]

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  1.001729  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786  0.984094 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929  0.998151 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  1.006648  0.050000
# ...                ...         ...       ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  1.007712  1.009995
# 2020-12-28  136.690002  131.970001  4.720001  1.035766  4.720001
# 2020-12-29  134.869995  136.690002 -1.820007  0.986685 -1.820007
# 2020-12-30  133.720001  134.869995 -1.149994  0.991473 -1.149994
# 2020-12-31  132.690002  133.720001 -1.029999  0.992297 -1.029999
#
# [2769 rows x 5 columns]

# %%
aapl['% Change 2']=aapl.AAPL.pct_change(periods=1).mul(100)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224  1.009995    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571  4.720001    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485 -1.820007   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668 -1.149994   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265 -1.029999   -0.770265
#
# [2769 rows x 6 columns]

# %%
del aapl['lag1']

# %%
aapl
# Out:
#                   AAPL  % Change 2
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    0.172893
# 2010-01-06    7.534643   -1.590632
# 2010-01-07    7.520714   -0.184871
# 2010-01-08    7.570714    0.664833
# ...                ...         ...
# 2020-12-24  131.970001    0.771224
# 2020-12-28  136.690002    3.576571
# 2020-12-29  134.869995   -1.331485
# 2020-12-30  133.720001   -0.852668
# 2020-12-31  132.690002   -0.770265
#
# [2769 rows x 2 columns]

# %%
aapl.rename(columns = {'% Change 2':'Daily Change'}, inplace = True)

# %%
aapl
# Out:
#                   AAPL  Daily Change
# Date
# 2010-01-04    7.643214           NaN
# 2010-01-05    7.656429      0.172893
# 2010-01-06    7.534643     -1.590632
# 2010-01-07    7.520714     -0.184871
# 2010-01-08    7.570714      0.664833
# ...                ...           ...
# 2020-12-24  131.970001      0.771224
# 2020-12-28  136.690002      3.576571
# 2020-12-29  134.869995     -1.331485
# 2020-12-30  133.720001     -0.852668
# 2020-12-31  132.690002     -0.770265
#
# [2769 rows x 2 columns]

# %%
aapl.AAPL.resample('M').last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-31    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: M, Name: AAPL, Length: 132, dtype: float64

# %%
#Business day of the month
aapl.AAPL.resample('BM').last()
# Out:
# Date
# 2010-01-29      6.859286
# 2010-02-26      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2020-08-31    129.039993
# 2020-09-30    115.809998
# 2020-10-30    108.860001
# 2020-11-30    119.050003
# 2020-12-31    132.690002
# Freq: BM, Name: AAPL, Length: 132, dtype: float64

# %%
#Monthly Percentage
aapl.AAPL.resample('BM').last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BM, Name: AAPL, Length: 132, dtype: float64

# %%
 del aapl['Daily Change']

# %%
aapl
# Out:
#                   AAPL
# Date
# 2010-01-04    7.643214
# 2010-01-05    7.656429
# 2010-01-06    7.534643
# 2010-01-07    7.520714
# 2010-01-08    7.570714
# ...                ...
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002
#
# [2769 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()
#dropna() deletes na rows

# %%
ret
# Out:
#                 AAPL
# Date
# 2010-01-05  0.001729
# 2010-01-06 -0.015906
# 2010-01-07 -0.001849
# 2010-01-08  0.006648
# 2010-01-11 -0.008821
# ...              ...
# 2020-12-24  0.007712
# 2020-12-28  0.035766
# 2020-12-29 -0.013315
# 2020-12-30 -0.008527
# 2020-12-31 -0.007703
#
# [2768 rows x 1 columns]

# %%
ret.plot(kind='hist', figsize=(12,8), bins=100)
plt.show()

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# AAPL    0.001191
# dtype: float64

# %%
var_daily=ret.var()
var_daily
# Out:
# AAPL    0.000318
# dtype: float64
